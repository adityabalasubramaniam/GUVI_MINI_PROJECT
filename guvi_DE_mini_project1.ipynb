# %%
import os

mongo_uri = os.getenv('MONGODB_URI')

# %%
pip install pymongo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pymongo import MongoClient

# Connect to MongoDB (default host and port)
client = MongoClient('mongodb://localhost:27017/')

# %%
# Create or access a database
db = client['myDatabase']

# Create or access a collection
collection = db['myCollection']

# %%
#reading the file
import pandas as pd
# import numpy as np

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# df=pd.read_excel(r'C:\Users\knowy\Downloads\census_2011.xlsx')
url = 'https://docs.google.com/spreadsheets/d/1YWdOUGGFy1h-WKuXtkiKDTm3jcEY4Y7XuSZt_rzXtgc/export?format=xlsx'
df = pd.read_excel(url)

# %%
url
# Out:
# 'https://docs.google.com/spreadsheets/d/1YWdOUGGFy1h-WKuXtkiKDTm3jcEY4Y7XuSZt_rzXtgc/export?format=xlsx'

# %%
df.shape
# Out:
# (640, 118)

# %%
df.head()
# Out:
#    District code         State name District name  Population      Male  \
# 0              1  JAMMU AND KASHMIR       Kupwara    870354.0  474190.0
# 1              2  JAMMU AND KASHMIR        Badgam    753745.0       NaN
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)    133487.0   78971.0
# 3              4  JAMMU AND KASHMIR        Kargil    140802.0       NaN
# 4              5  JAMMU AND KASHMIR         Punch         NaN  251899.0
#
#      Female  Literate  Male_Literate  Female_Literate      SC  ...  \
# 0  396164.0  439654.0       282823.0         156831.0  1048.0  ...
# 1  355704.0  335649.0       207741.0         127908.0     NaN  ...
# 2   54516.0   93770.0        62834.0          30936.0   488.0  ...
# 3   63017.0       NaN        56301.0          29935.0    18.0  ...
# 4  224936.0  261724.0       163333.0          98391.0   556.0  ...
#
#    Power_Parity_Rs_90000_150000  Power_Parity_Rs_45000_150000  \
# 0                          94.0                         588.0
# ...

# %%
df.columns.to_list()
# Out:
# ['District code',
#  'State name',
#  'District name',
#  'Population',
#  'Male',
#  'Female',
#  'Literate',
#  'Male_Literate',
#  'Female_Literate',
#  'SC',
#  'Male_SC',
#  'Female_SC',
#  'ST',
#  'Male_ST',
#  'Female_ST',
#  'Workers',
#  'Male_Workers',
#  'Female_Workers',
#  'Main_Workers',
#  'Marginal_Workers',
#  'Non_Workers',
#  'Cultivator_Workers',
#  'Agricultural_Workers',
#  'Household_Workers',
#  'Other_Workers',
#  'Hindus',
#  'Muslims',
#  'Christians',
#  'Sikhs',
#  'Buddhists',
#  'Jains',
#  'Others_Religions',
#  'Religion_Not_Stated',
#  'LPG_or_PNG_Households',
#  'Housholds_with_Electric_Lighting',
#  'Households_with_Internet',
#  'Households_with_Computer',
#  'Rural_Households',
#  'Urban_Households',
#  'Households',
#  'Below_Primary_Education',
#  'Primary_Education',
#  'Middle_Education',
#  'Secondary_Education',
#  'Higher_Education',
#  'Graduate_Education',
#  'Other_Education',
#  'Literate_Education',
#  'Illiterate_Education',
# ...

# %% [markdown]
# Renaming the column names as per the task1 requirement.

# %%
df.rename(columns={'State name':'State/UT',
                    'District name': 'District',
                      'Male_Literate':'Literate_Male',
                        'Female_Literate':'Literate_Female',
                        'Rural_Households':'Households_Rural',
                        'Urban_Households':'Households_Urban',
                        'Age_Group_0_29': 'Young_and_Adult',
                        'Age_Group_30_49': 'Middle_Aged',
                        'Age_Group_50' : 'Senior_Citizen',
                        'Age not stated': 'Age_Not_Stated',}, inplace=True)

# %% [markdown]
# proceeding to task2: (Rename state/UT names)

# %%
df
# Out:
#      District code                     State/UT                   District  \
# 0                1            JAMMU AND KASHMIR                    Kupwara
# 1                2            JAMMU AND KASHMIR                     Badgam
# 2                3            JAMMU AND KASHMIR                Leh(Ladakh)
# 3                4            JAMMU AND KASHMIR                     Kargil
# 4                5            JAMMU AND KASHMIR                      Punch
# ..             ...                          ...                        ...
# 635            636                  PONDICHERRY                       Mahe
# 636            637                  PONDICHERRY                   Karaikal
# 637            638  ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 638            639  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 639            640  ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
# ...

# %%
df['State/UT'].unique()
# Out:
# array(['JAMMU AND KASHMIR', 'HIMACHAL PRADESH', 'PUNJAB', 'CHANDIGARH',
#        'UTTARAKHAND', 'HARYANA', 'NCT OF DELHI', 'RAJASTHAN',
#        'UTTAR PRADESH', 'BIHAR', 'SIKKIM', 'ARUNACHAL PRADESH',
#        'NAGALAND', 'MANIPUR', 'MIZORAM', 'TRIPURA', 'MEGHALAYA', 'ASSAM',
#        'WEST BENGAL', 'JHARKHAND', 'ORISSA', 'CHHATTISGARH',
#        'MADHYA PRADESH', 'GUJARAT', 'DAMAN AND DIU',
#        'DADRA AND NAGAR HAVELI', 'MAHARASHTRA', 'ANDHRA PRADESH',
#        'KARNATAKA', 'GOA', 'LAKSHADWEEP', 'KERALA', 'TAMIL NADU',
#        'PONDICHERRY', 'ANDAMAN AND NICOBAR ISLANDS'], dtype=object)

# %%
df['State/UT'] = df['State/UT'].str.title()

# %%
df['State/UT'] = df['State/UT'].str.replace(' And ', ' and ', case=False)

# %%
df['District'] = df['District'].str.replace('Leh(Ladakh)', 'Leh', case=False)

# %%
df['State/UT'].unique()
# Out:
# array(['Jammu and Kashmir', 'Himachal Pradesh', 'Punjab', 'Chandigarh',
#        'Uttarakhand', 'Haryana', 'Nct Of Delhi', 'Rajasthan',
#        'Uttar Pradesh', 'Bihar', 'Sikkim', 'Arunachal Pradesh',
#        'Nagaland', 'Manipur', 'Mizoram', 'Tripura', 'Meghalaya', 'Assam',
#        'West Bengal', 'Jharkhand', 'Orissa', 'Chhattisgarh',
#        'Madhya Pradesh', 'Gujarat', 'Daman and Diu',
#        'Dadra and Nagar Haveli', 'Maharashtra', 'Andhra Pradesh',
#        'Karnataka', 'Goa', 'Lakshadweep', 'Kerala', 'Tamil Nadu',
#        'Pondicherry', 'Andaman and Nicobar Islands'], dtype=object)

# %% [markdown]
# Proceding task 3:(New State/UT formation)

# %%
df['State/UT'] = df['State/UT'].str.replace(' Andhra Pradesh ', ' Telangana ', case=False)

# %%
df['State/UT'] = df['State/UT'].str.replace(' Jammu and Kashmir ', ' Ladakh ', case=False)

# %%
df.loc[df['District'] == ('Leh' and 'Kargil'), 'State/UT'] = 'Ladakh'

# %%
df.loc[df['District'] == ('Leh'), 'State/UT'] = 'Ladakh'

# %%
df.loc[df['District'] == ('Adilabad'), 'State/UT'] = 'Telangana'
df.loc[df['District'] == ('Nizamabad'), 'State/UT'] = 'Telangana'
df.loc[df['District'] == ('Karimnagar'), 'State/UT'] = 'Telangana'
df.loc[df['District'] == ('Medak'), 'State/UT'] = 'Telangana'
df.loc[df['District'] == ('Hyderabad'), 'State/UT'] = 'Telangana'
df.loc[df['District'] == ('Rangareddy'), 'State/UT'] = 'Telangana'
df.loc[df['District'] == ('Mahbubnagar'), 'State/UT'] = 'Telangana'
df.loc[df['District'] == ('Nalgonda'), 'State/UT'] = 'Telangana'
df.loc[df['District'] == ('Warangal'), 'State/UT'] = 'Telangana'
df.loc[df['District'] == ('Khammam'), 'State/UT'] = 'Telangana'

# %%
df.loc[df['District'] == ('Nizamabad'), 'State/UT'] = 'Telangana'

# %%
df.loc[df['District'] == (('Adilabad' and 'Nizamabad' and 'Karimnagar' and 'Medak' and 'Hyderabad' and 'Rangareddy' and 'Mahbubnagar' and 'Nalgonda' and 'Warangal' and 'Khammam')), 'State/UT'] = 'Telangana'

# %%
df
# Out:
#      District code                     State/UT                   District  \
# 0                1            Jammu and Kashmir                    Kupwara
# 1                2            Jammu and Kashmir                     Badgam
# 2                3                       Ladakh                        Leh
# 3                4                       Ladakh                     Kargil
# 4                5            Jammu and Kashmir                      Punch
# ..             ...                          ...                        ...
# 635            636                  Pondicherry                       Mahe
# 636            637                  Pondicherry                   Karaikal
# 637            638  Andaman and Nicobar Islands                   Nicobars
# 638            639  Andaman and Nicobar Islands  North  AND Middle Andaman
# 639            640  Andaman and Nicobar Islands              South Andaman
#
# ...

# %%
df['State/UT'].unique()
# Out:
# array(['Jammu and Kashmir', 'Ladakh', 'Himachal Pradesh', 'Punjab',
#        'Chandigarh', 'Uttarakhand', 'Haryana', 'Nct Of Delhi',
#        'Rajasthan', 'Uttar Pradesh', 'Bihar', 'Sikkim',
#        'Arunachal Pradesh', 'Nagaland', 'Manipur', 'Mizoram', 'Tripura',
#        'Meghalaya', 'Assam', 'West Bengal', 'Jharkhand', 'Orissa',
#        'Chhattisgarh', 'Madhya Pradesh', 'Gujarat', 'Daman and Diu',
#        'Dadra and Nagar Haveli', 'Maharashtra', 'Telangana',
#        'Andhra Pradesh', 'Karnataka', 'Goa', 'Lakshadweep', 'Kerala',
#        'Tamil Nadu', 'Pondicherry', 'Andaman and Nicobar Islands'],
#       dtype=object)

# %%
a= df[df['District'] == 'Kargil']

# %%
a
# Out:
#    District code State/UT District  Population  Male   Female  Literate  \
# 3              4   Ladakh   Kargil    140802.0   NaN  63017.0       NaN
#
#    Literate_Male  Literate_Female    SC  ...  Power_Parity_Rs_90000_150000  \
# 3        56301.0          29935.0  18.0  ...                          27.0
#
#    Power_Parity_Rs_45000_150000  Power_Parity_Rs_150000_240000  \
# 3                         114.0                           12.0
#
#    Power_Parity_Rs_240000_330000  Power_Parity_Rs_150000_330000  \
# 3                           18.0                           30.0
#
#    Power_Parity_Rs_330000_425000  Power_Parity_Rs_425000_545000  \
# 3                           19.0                            3.0
#
#    Power_Parity_Rs_330000_545000  Power_Parity_Above_Rs_545000  \
# 3                           22.0                           7.0
#
#    Total_Power_Parity
# 3               214.0
#
# [1 rows x 118 columns]

# %% [markdown]
# Proceding to the next Task 4 - find and processing Missing data

# %%
missing_percentage_before = df.isnull().mean() * 100
print("Percentage of missing data before filling:")
print(missing_percentage_before)
missing_percentage_before.to_list()
# Out:
# Percentage of missing data before filling:
# District code                    0.00000
# State/UT                         0.00000
# District                         0.00000
# Population                       4.68750
# Male                             4.68750
#                                   ...
# Power_Parity_Rs_330000_425000    5.15625
# Power_Parity_Rs_425000_545000    4.68750
# Power_Parity_Rs_330000_545000    3.59375
# Power_Parity_Above_Rs_545000     4.68750
# Total_Power_Parity               5.00000
# Length: 118, dtype: float64
# [0.0,
#  0.0,
#  0.0,
#  4.6875,
#  4.6875,
#  5.15625,
#  5.625,
#  4.84375,
#  4.21875,
#  5.46875,
#  3.5937499999999996,
#  5.0,
#  4.53125,
#  4.84375,
#  4.84375,
#  3.5937499999999996,
#  3.4375000000000004,
#  2.96875,
#  4.375,
#  6.09375,
#  5.625,
#  4.53125,
#  4.21875,
#  4.375,
#  4.375,
#  4.21875,
#  5.78125,
#  4.6875,
#  4.53125,
#  4.0625,
#  6.5625,
#  4.6875,
#  5.46875,
#  5.78125,
#  6.406249999999999,
#  3.5937499999999996,
# ...

# %%
pd.reset_option('display.max_columns')

# %%
df['Population'] = df['Male'] + df['Female']
df['Literate'] = df['Literate_Male'] + df['Literate_Female']

# Filling missing values using .loc to avoid chained assignment warnings
df.loc[df['Population'].isnull(), 'Population'] = (
    df['Young_and_Adult'] + df['Middle_Aged'] + df['Senior_Citizen'] + df['Age_Not_Stated']
)

df.loc[df['Households'].isnull(), 'Households'] = (
    df['Households_Rural'] + df['Households_Urban']
)

# %%
df
# Out:
#      District code                     State/UT                   District  \
# 0                1            Jammu and Kashmir                    Kupwara
# 1                2            Jammu and Kashmir                     Badgam
# 2                3                       Ladakh                        Leh
# 3                4                       Ladakh                     Kargil
# 4                5            Jammu and Kashmir                      Punch
# ..             ...                          ...                        ...
# 635            636                  Pondicherry                       Mahe
# 636            637                  Pondicherry                   Karaikal
# 637            638  Andaman and Nicobar Islands                   Nicobars
# 638            639  Andaman and Nicobar Islands  North  AND Middle Andaman
# 639            640  Andaman and Nicobar Islands              South Andaman
#
# ...

# %%
# Step 4: Calculate percentage of missing data for each column after filling
missing_percentage_after = df.isnull().mean() * 100
print("\nPercentage of missing data after filling:")
print(missing_percentage_after)
# Out:
# Percentage of missing data after filling:
# District code                    0.00000
# State/UT                         0.00000
# District                         0.00000
# Population                       1.71875
# Male                             4.68750
#                                   ...
# Power_Parity_Rs_330000_425000    5.15625
# Power_Parity_Rs_425000_545000    4.68750
# Power_Parity_Rs_330000_545000    3.59375
# Power_Parity_Above_Rs_545000     4.68750
# Total_Power_Parity               5.00000
# Length: 118, dtype: float64

# %%
# Step 5: Compare the two percentages
comparison = pd.DataFrame({
    'Before Filling': missing_percentage_before,
    'After Filling': missing_percentage_after
})

print("\nComparison of missing data percentages:")
print(comparison)
# Out:
# Comparison of missing data percentages:
#                                Before Filling  After Filling
# District code                         0.00000        0.00000
# State/UT                              0.00000        0.00000
# District                              0.00000        0.00000
# Population                            4.68750        1.71875
# Male                                  4.68750        4.68750
# ...                                       ...            ...
# Power_Parity_Rs_330000_425000         5.15625        5.15625
# Power_Parity_Rs_425000_545000         4.68750        4.68750
# Power_Parity_Rs_330000_545000         3.59375        3.59375
# Power_Parity_Above_Rs_545000          4.68750        4.68750
# Total_Power_Parity                    5.00000        5.00000
#
# [118 rows x 2 columns]

# %% [markdown]
# Step-5 - save data to MangoDB

# %%
# Step 1: Set up MongoDB connection
client = MongoClient('mongodb://localhost:27017/')  # Update the connection string if necessary
db = client['myDatabase']  # Replace with your database name
collection = db['census']  #updated db name

# Step 2: Convert DataFrame to a list of dictionaries
data_to_insert = df.to_dict(orient='records')

# Step 3: Insert data into MongoDB
collection.insert_many(data_to_insert)

print("Data has been successfully saved to MongoDB in the 'census' collection.")
# Out:
# Data has been successfully saved to MongoDB in the 'census' collection.

# %% [markdown]
# Step - 6 - Database connection and data upload

# %%
pip install pymongo sqlalchemy mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install psycopg2-binary
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sqlalchemy import create_engine, MetaData

# %%
from sqlalchemy import create_engine, MetaData, Table, Column, Integer, String, ForeignKey

# Connect to the SQL database
engine = create_engine('postgresql://username:password@localhost:5432/census')

# Define metadata for tables
metadata = MetaData()

# Create census table
census_table = Table('census', metadata,
                     Column('id', Integer, primary_key=True),
                     Column('district', String),
                     Column('Male', Integer),
                     Column('Female', Integer),
                     Column('Literate_Male', Integer),
                     Column('Literate_Female', Integer),
                    
)

# Create the table in the database
metadata.create_all(engine)

# Fetch data from MongoDB and insert into SQLx``
df.to_sql('census', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\knowy\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145 try:
# --> 146     self._dbapi_connection = engine.raw_connection()
#     147 except dialect.loaded_dbapi.Error as err:
#
# File c:\Users\knowy\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\base.py:3302, in Engine.raw_connection(self)
#    3281 """Return a "raw" DBAPI connection from the connection pool.
#    3282
#    3283 The returned object is a proxied version of the DBAPI
#    (...)
#    3300
#    3301 """
# -> 3302 return self.pool.connect()
#
# File c:\Users\knowy\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\pool\base.py:449, in Pool.connect(self)
# ...

# %% [markdown]
# Step - 7 - Run Querry on the database and show output on the streamlit.

# %%
from sqlalchemy import create_engine, MetaData
from sqlalchemy.exc import OperationalError

# Define your connection parameters
username = 'your_username'
password = 'your_password'
database = 'your_database'
host = 'localhost'
port = '5432'

# Create the connection string
connection_string = f'postgresql://{username}:{password}@{host}:{port}/{database}'

try:
    # Create an engine
    engine = create_engine(connection_string)

    # Create a MetaData instance
    metadata = MetaData()

    # Reflect the database schema
    metadata.reflect(bind=engine)

    # Access a specific table
    my_table = metadata.tables['your_table_name']

    # Example: print table information
    print(my_table.columns.keys())

except OperationalError as e:
    print("Could not connect to the database. Please check your connection settings.")
    print(f"Error: {e}")

except Exception as e:
    print("An unexpected error occurred.")
    print(f"Error: {e}")
# Out:
# Could not connect to the database. Please check your connection settings.
# Error: (psycopg2.OperationalError) connection to server at "localhost" (::1), port 5432 failed: Connection refused (0x0000274D/10061)
# 	Is the server running on that host and accepting TCP/IP connections?
# connection to server at "localhost" (127.0.0.1), port 5432 failed: Connection refused (0x0000274D/10061)
# 	Is the server running on that host and accepting TCP/IP connections?
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
import pymongo

# Replace with your MongoDB connection string
client = pymongo.MongoClient("mongodb://localhost:27017/")

# Specify the database name
db = client["your_database_name"]

# Specify the collection name
collection = db["your_collection_name"]
